# %% [markdown]
# # Moving Average Crossover
#
# The standard pattern used by every notebook in this repo: **load data, instantiate an algorithm, run the backtest, print stats, show charts.**

# %%
from data import get_prices
from algorithm import MovingAverageCrossover
from backtest import Backtester, build_report

# %%
from datetime import date

TICKER, BENCHMARK = "AAPL", "SPY"
START, END = "2018-01-01", date.today().isoformat()  # through today

prices = get_prices([TICKER], START, END)
benchmark = get_prices([BENCHMARK], START, END)[BENCHMARK]
prices.tail()
# Out:
#                   AAPL
# Date
# 2026-06-24  293.079987
# 2026-06-25  275.149994
# 2026-06-26  283.779999
# 2026-06-29  281.739990
# 2026-06-30  289.359985

# %%
algorithm = MovingAverageCrossover(TICKER, short_window=20, long_window=100)
result = Backtester().run(algorithm, prices, initial_capital=100_000, commission_bps=5, slippage_bps=5)
result.equity.tail()
# Out:
# Date
# 2026-06-24    279453.338095
# 2026-06-25    262356.993975
# 2026-06-26    270585.749887
# 2026-06-29    268640.590805
# 2026-06-30    275906.296992
# dtype: float64

# %%
report = build_report(result, benchmark_prices=benchmark)
report.stats
# Out:
# {'total_return': np.float64(1.7590629699202323),
#  'cagr': np.float64(0.12732386321638356),
#  'annual_volatility': np.float64(0.23448398746117832),
#  'sharpe': 0.6286563030481667,
#  'sortino': 0.6941635992653641,
#  'max_drawdown': -0.35640906954459606,
#  'calmar': np.float64(0.35724080585006557),
#  'win_rate': 0.5196078431372549,
#  'trade_count': 29,
#  'benchmark_total_return': np.float64(2.1648934261118344),
#  'benchmark_cagr': np.float64(0.1457409961792573)}

# %%
for fig in report.figures:
    fig.show()
